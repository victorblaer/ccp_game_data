# %% [markdown]
# <a href="https://colab.research.google.com/github/victorblaer/ccp_game_data/blob/main/ccp_game_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = 'https://raw.githubusercontent.com/victorblaer/ccp_game_data/main/test_dataset_sample.csv'
df1 = pd.read_csv(url)

# %% [markdown]
# Summarize data

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120000 entries, 0 to 119999
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Unnamed: 0                        120000 non-null  int64
#  1   reference_date                    120000 non-null  object
#  2   user_id                           120000 non-null  int64
#  3   user_tenure_in_days               120000 non-null  int64
#  4   logon_count                       120000 non-null  int64
#  5   logon_hours                       120000 non-null  int64
#  6   number_of_characters_logged_in    120000 non-null  int64
#  7   net_currency_flow_through_wallet  120000 non-null  float64
#  8   currency_spent_to_buy             120000 non-null  float64
#  9   number_of_items_bought            120000 non-null  float64
#  10  currency_gained_from_selling      120000 non-null  float64
# ...

# %%
df1['reference_date'] = df1['reference_date'].astype('datetime64[ns]')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120000 entries, 0 to 119999
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Unnamed: 0                        120000 non-null  int64
#  1   reference_date                    120000 non-null  datetime64[ns]
#  2   user_id                           120000 non-null  int64
#  3   user_tenure_in_days               120000 non-null  int64
#  4   logon_count                       120000 non-null  int64
#  5   logon_hours                       120000 non-null  int64
#  6   number_of_characters_logged_in    120000 non-null  int64
#  7   net_currency_flow_through_wallet  120000 non-null  float64
#  8   currency_spent_to_buy             120000 non-null  float64
#  9   number_of_items_bought            120000 non-null  float64
#  10  currency_gained_from_selling      120000 non-null  float64
# ...

# %%
df1.describe()
# Out:
#          Unnamed: 0       user_id  user_tenure_in_days    logon_count  \
# count  1.200000e+05  1.200000e+05        120000.000000  120000.000000
# mean   1.764364e+06  1.783708e+07          2068.284817       8.864458
# std    1.016307e+06  8.720581e+06          1936.288888       8.801974
# min    2.000000e+01  9.700000e+02             0.000000       1.000000
# 25%    8.870165e+05  1.075204e+07           389.000000       2.000000
# 50%    1.769091e+06  1.876439e+07          1456.000000       7.000000
# 75%    2.644274e+06  2.613934e+07          3465.000000      12.000000
# max    3.523622e+06  2.928780e+07          7515.000000     689.000000
#
#          logon_hours  number_of_characters_logged_in  \
# count  120000.000000                   120000.000000
# mean       13.188408                        3.915967
# std        24.084395                        3.583729
# min         0.000000                        0.000000
# 25%         0.000000                        1.000000
# ...

# %% [markdown]
# We see an un-named column. Most likely the data table index, which is lost upon csv export. Let's rename and look at the distribution.

# %%
df1.rename(columns={'Unnamed: 0':'xyz'}, inplace = True)
df1.head()
# Out:
#        xyz reference_date   user_id  user_tenure_in_days  logon_count  \
# 0   640631     2023-03-01  27830816                    4            1
# 1  2732287     2023-10-01  28913852                    3            3
# 2  2687723     2023-10-01  28829269                   22            1
# 3  1219571     2023-05-01    425695                 6582           40
# 4  1030427     2023-04-01  25298329                  486           33
#
#    logon_hours  number_of_characters_logged_in  \
# 0            0                               1
# 1            2                               3
# 2            0                               1
# 3           27                              22
# 4           51                              13
#
#    net_currency_flow_through_wallet  currency_spent_to_buy  \
# 0                               0.0                    0.0
# 1                           -2280.0                    0.0
# 2                               0.0                    0.0
# ...

# %%
df1.sort_values(by='xyz')
# Out:
#             xyz reference_date   user_id  user_tenure_in_days  logon_count  \
# 45761        20     2023-01-01  23677641                  688            1
# 33136        29     2023-01-01  21091398                  981           14
# 79827        65     2023-01-01  24828977                  475           13
# 59337       143     2023-01-01  11377426                 3079           11
# 88280       182     2023-01-01  18027569                 1394            8
# ...         ...            ...       ...                  ...          ...
# 58244   3523540     2023-12-01  24290939                  926           26
# 105916  3523553     2023-12-01  11022804                 3556            3
# 97712   3523575     2023-12-01  25019429                  783            1
# 101778  3523594     2023-12-01   1376302                 6294           11
# 99031   3523622     2023-12-01  29063142                   28            6
#
#         logon_hours  number_of_characters_logged_in  \
# ...

# %% [markdown]
# Looks like a random sample of indexes, let's plot a few histograms and see the distribution

# %%
df1.hist(column = 'xyz')
# Out:
# array([[<Axes: title={'center': 'xyz'}>]], dtype=object)

# %% [markdown]
# Looks like a uniform sample, i.e. all samples are of equal probability.

# %%
## Before heading over to tableau, let's look at few histograms
## Info bc it's easier to copy column names
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120000 entries, 0 to 119999
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   xyz                               120000 non-null  int64
#  1   reference_date                    120000 non-null  datetime64[ns]
#  2   user_id                           120000 non-null  int64
#  3   user_tenure_in_days               120000 non-null  int64
#  4   logon_count                       120000 non-null  int64
#  5   logon_hours                       120000 non-null  int64
#  6   number_of_characters_logged_in    120000 non-null  int64
#  7   net_currency_flow_through_wallet  120000 non-null  float64
#  8   currency_spent_to_buy             120000 non-null  float64
#  9   number_of_items_bought            120000 non-null  float64
#  10  currency_gained_from_selling      120000 non-null  float64
# ...

# %% [markdown]
# I'm sure there's a much smarter way to plot these, including to view by [wiil_churn] but I'm running out of time ⏰

# %%
df1.hist(column = 'user_tenure_in_days')
df2 = df1.hist(column = 'logon_hours')
df3 = df1.hist(column = 'number_of_characters_logged_in')
df4 = df1.hist(column = 'currency_spent_to_buy')
df5 = df1.hist(column = 'currency_gained_from_selling')
df6 = df1.hist(column = 'number_of_items_bought')
df7 = df1.hist(column = 'number_of_items_sold')
df8 = df1.hist(column = 'mining_units')
df9 = df1.hist(column = 'will_churn')

# %% [markdown]
# Let's head over to tableau for the analysis part

# %%
import seaborn as sns

# %%
df1.corr()
# Out:
# <ipython-input-24-49b3fcfeb4d1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                                        xyz   user_id  user_tenure_in_days  \
# xyz                               1.000000  0.033521             0.026900
# user_id                           0.033521  1.000000            -0.983612
# user_tenure_in_days               0.026900 -0.983612             1.000000
# logon_count                       0.004955 -0.076536             0.070867
# logon_hours                       0.003368 -0.052476             0.051429
# number_of_characters_logged_in    0.013005 -0.111060             0.109204
# net_currency_flow_through_wallet  0.005333 -0.002334             0.002631
# currency_spent_to_buy            -0.001385 -0.013971             0.011628
# ...

# %% [markdown]
# I don't know about you but I can't see much out of this..let's plot

# %%
sns.heatmap(df1.corr());
# Out:
# <ipython-input-27-3bd50b997003>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr());

# %%
heatmap = sns.heatmap(df1.corr()[['will_churn']].sort_values(by='will_churn', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with will_churn', fontdict={'fontsize':18}, pad=16);
# Out:
# <ipython-input-32-c329364421bc>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(df1.corr()[['will_churn']].sort_values(by='will_churn', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')

# %% [markdown]
# Hmm, this can't be right, but I'm out of time 😢

# %%
def format_float(value):
    return f'{value:,.2f}'

pd.options.display.float_format = format_float

# %%
df1.mean()
# Out:
# <ipython-input-41-00fb6bfec183>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df1.mean()
# xyz                                  1,764,364.41
# user_id                             17,837,075.13
# user_tenure_in_days                      2,068.28
# logon_count                                  8.86
# logon_hours                                 13.19
# number_of_characters_logged_in               3.92
# net_currency_flow_through_wallet    37,682,715.66
# currency_spent_to_buy              545,148,260.56
# number_of_items_bought                      14.87
# currency_gained_from_selling       586,912,144.58
# number_of_items_sold                        14.44
# number_of_deaths                             0.55
# mining_units                           156,998.43
# will_churn                                   0.14
# dtype: float64

# %%
import seaborn as sns

# %%
#https://www.datacamp.com/tutorial/how-to-make-a-seaborn-histogram
#lt.figure(figsize=(10, 6))
sns.histplot(data=df1, x='user_tenure_in_days', hue='will_churn')
plt.title('Will Churn')
plt.xlabel('user_tenure_in_days)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#https://www.datacamp.com/tutorial/how-to-make-a-seaborn-histogram
#lt.figure(figsize=(10, 6))
sns.histplot(data=df1, x='logon_count', hue='will_churn')
plt.title('Log on count doesnt tell us anything bc of extreme values')
plt.xlabel('long_count)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#https://www.datacamp.com/tutorial/how-to-make-a-seaborn-histogram
#lt.figure(figsize=(10, 6))
sns.histplot(data=df1, x='number_of_items_bought', hue='will_churn')
plt.title('Will Churn')
plt.xlabel('user_tenure_in_days)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-5e519a6775d1> in <cell line: 3>()
#       1 #https://www.datacamp.com/tutorial/how-to-make-a-seaborn-histogram
#       2 #lt.figure(figsize=(10, 6))
# ----> 3 sns.histplot(data=df1, x='number_of_items_bought', hue='will_churn')
#       4 plt.title('Will Churn')
#       5 plt.xlabel('user_tenure_in_days)')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1414     if p.univariate:
#    1415
# -> 1416         p.plot_univariate_histogram(
#    1417             multiple=multiple,
# ...

# %%
seaborn.scatterplot(x='user_tenure_in_days', y='logon_count', data=df1, hue='will_churn', palette='pastel')

# %%
sns.scatterplot(x='user_tenure_in_days', y='logon_count', data=df1, hue='will_churn', palette='pastel')
# Out:
# <Axes: xlabel='user_tenure_in_days', ylabel='logon_count'>

# %%
# Let's filter on will churn
will_churn = df1['will_churn'] > 0
#setosa = data[data.variety == "Setosa"]
will_churn.head()
# Out:
#   File "<ipython-input-14-6dd9db34ba80>", line 2
#     will_churn = df1[df1.'will_churn'] > 0
#                          ^
# SyntaxError: invalid syntax

# %%
filtered_df_will_churn = df1.loc[df1['will_churn'] > 0]

# %%
sns.scatterplot(x='user_tenure_in_days', y='logon_count', data=filtered_df_will_churn, hue='will_churn', palette='pastel')
# Out:
# <Axes: xlabel='user_tenure_in_days', ylabel='logon_count'>

# %%
filtered_df_no_churn = df1.loc[df1['will_churn'] == 0]
sns.scatterplot(x='user_tenure_in_days', y='logon_count', data=filtered_df_no_churn, hue='will_churn', palette='pastel')
# Out:
# <Axes: xlabel='user_tenure_in_days', ylabel='logon_count'>

# %%
def format_float(value):
    return f'{value:,.2f}'

pd.options.display.float_format = format_float
filtered_df_no_churn.mean()
# Out:
# <ipython-input-23-a5a4338b06df>:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   filtered_df_no_churn.mean()
# Unnamed: 0                           1,781,196.39
# user_id                             17,277,969.66
# user_tenure_in_days                      2,182.75
# logon_count                                  9.96
# logon_hours                                 15.10
# number_of_characters_logged_in               4.35
# net_currency_flow_through_wallet    40,094,152.91
# currency_spent_to_buy              625,488,593.57
# number_of_items_bought                      16.95
# currency_gained_from_selling       670,353,122.20
# number_of_items_sold                        16.41
# number_of_deaths                             0.56
# ...

# %%
filtered_df_will_churn.mean()
# Out:
# <ipython-input-24-1c89ae6c7d53>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   filtered_df_will_churn.mean()
# Unnamed: 0                          1,660,846.15
# user_id                            21,275,625.45
# user_tenure_in_days                     1,364.30
# logon_count                                 2.14
# logon_hours                                 1.46
# number_of_characters_logged_in              1.23
# net_currency_flow_through_wallet   22,852,153.84
# currency_spent_to_buy              51,047,792.65
# number_of_items_bought                      2.06
# currency_gained_from_selling       73,742,426.02
# number_of_items_sold                        2.35
# number_of_deaths                            0.44
# ...

# %%
sns.relplot(
    data=df1,
    x="user_tenure_in_days", y="logon_count", hue="will_churn", col="will_churn",
)
